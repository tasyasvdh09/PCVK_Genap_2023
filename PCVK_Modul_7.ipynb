# %% [markdown]
# <a href="https://colab.research.google.com/github/tasyasvdh09/PCVK_Genap_2023/blob/main/PCVK_Modul_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASYA SEVIA ADHA | TI-3D | 17 | 2041720031

# %%
#import folder yang ada di drive

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import library
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import math
from google.colab.patches import cv2_imshow
from PIL import Image as im

# %%
#membuat fungsi konvolusi tanpa library
def convolution2d(image, kernel, stride, padding):
  image = np.pad(image, padding, mode='constant', constant_values=0)

  #height dan width dari kernel dan citra padding
  paddingheight, paddingwidth = image.shape
  kernelheight, kernelwidth = kernel.shape

  #menenteukan output
  outputheight = (paddingheight - kernelheight) // stride + 1
  outputwidth = (paddingwidth - kernelwidth) // stride + 1

  new_image = np.zeros((outputheight, outputwidth)).astype(np.float32)

  for y in range(0, outputheight):
    for x in range(0, outputwidth):
      new_image[y][x] = np.sum(image[y * stride:y * stride + kernelheight, 
                                     x * stride:x * stride + kernelwidth] 
                                    * kernel).astype(np.float32)
  return new_image

# %%
#Load citra yang akan diproses dan ubah menjadi citra keabuan
img = cv.imread('/content/drive/MyDrive/PCVK/images/female.tiff')
img_gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# %%
#image sharpen
ernel_sharpen = np.array([[0,-1,0],
                            [-1,5,-1],
                            [0,-1,0]])

# %%
#image filter operasi sharpen
img_sharpen = img_gray.copy()
img_sharpen = convolution2d(img_sharpen, kernel_sharpen,1,0)

plt.title("Sharpen")
plt.imshow(img_sharpen, cmap='gray',vmin=0, vmax=255)

# %%
#image emboss
kernel_emboss = np.array([[-2,-1,0],
                        [-1,1,1],
                        [0,1,2]])

# %%
#image filter operasi emboss
img_emboss = img_gray.copy()
img_emboss = convolution2d(img_emboss, kernel_emboss,1,0)

plt.title("Emboss")
plt.imshow(img_emboss, cmap='gray',vmin=0, vmax=255)

# %%
#image Left Sobel Edge Detection (LSED)
kernel_LSED = np.array([[1,0,-1],
                        [2,0,-2],
                        [1,0,-1]])

# %%
#image filter operasi LSED
img_LSED = img_gray.copy()
img_LSED = convolution2d(img_LSED, kernel_LSED,1,0)

plt.title("LSED")
plt.imshow(img_LSED, cmap='gray',vmin=0, vmax=255)

# %%
#image Canny Edge Detection (CED)
kernel_CED = np.array([[-1,-1,-1],
                        [-1,8,-1],
                        [-1,-1,-1]])

# %%
#image filter operasi CED
img_CED = img_gray.copy()
img_CED = convolution2d(img_CED, kernel_CED,1,0)

plt.title("CED")
plt.imshow(img_CED, cmap='gray',vmin=0, vmax=255)

# %%
#image Prewitt Edge Detection (PED)
kernel_PED = np.array([[-1,-1,-1],
                        [0,0,0],
                        [1,1,1]])

# %%
#image filter operasi PED
img_PED = img_gray.copy()
img_PED = convolution2d(img_PED, kernel_PED,1,0)

plt.title("PED")
plt.imshow(img_PED, cmap='gray',vmin=0, vmax=255)
