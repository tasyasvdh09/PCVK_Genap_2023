# %% [markdown]
# <a href="https://colab.research.google.com/github/tasyasvdh09/PCVK_Genap_2023/blob/main/PCVK_Modul_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TASYA SEVIA ADHA / 3D / 17 / 2041720031**

# %% [markdown]
# ## **FACE DETECTION**

# %%
# import folder yang ada di drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import library
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **1.) Lakukan Face Detection untuk image object lain yang tersedia pada (/images/facedet).**

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/fitur-facedet/haarcascade_frontalface_alt.xml')

jokowi = cv2.imread('/content/drive/MyDrive/PCVK/images/jokowi.jpg')

# Clone the original image for displaying the detected faces
detected_faces = jokowi.copy()

roi_wajah = cascade_wajah.detectMultiScale(jokowi)
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(detected_faces, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Create subplots to display original and detected faces
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the original image
plt.subplot(121)
plt.imshow(cv2.cvtColor(jokowi, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

# Plot the image with detected faces
plt.subplot(122)
plt.imshow(cv2.cvtColor(detected_faces, cv2.COLOR_BGR2RGB))
plt.title('Detected Faces')
plt.axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/fitur-facedet/haarcascade_frontalface_alt.xml')

kartini = cv2.imread('/content/drive/MyDrive/PCVK/images/kartini.jpg')

# Clone the original image for displaying the detected faces
detected_faces = kartini.copy()

roi_wajah = cascade_wajah.detectMultiScale(kartini)
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(detected_faces, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Create subplots to display original and detected faces
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the original image
axes[0].imshow(cv2.cvtColor(kartini, cv2.COLOR_BGR2RGB))
axes[0].set_title('Original Image')

# Plot the image with detected faces
axes[1].imshow(cv2.cvtColor(detected_faces, cv2.COLOR_BGR2RGB))
axes[1].set_title('Detected Faces')

# Hide the axis labels
for ax in axes:
    ax.axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/fitur-facedet/haarcascade_frontalface_alt.xml')

cat = cv2.imread('/content/drive/MyDrive/PCVK/images/mycat.jpg')

# Clone the original image for displaying the detected faces
detected_faces = cat.copy()

roi_wajah = cascade_wajah.detectMultiScale(cat)
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(detected_faces, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Create subplots to display original and detected faces
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the original image in grayscale
axes[0].imshow(cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[0].set_title('Original Image')

# Plot the image with detected faces in grayscale
axes[1].imshow(cv2.cvtColor(detected_faces, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[1].set_title('Detected Faces')

# Hide the axis labels
for ax in axes:
    ax.axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/fitur-facedet/haarcascade_frontalface_alt.xml')

mask = cv2.imread('/content/drive/MyDrive/PCVK/images/mask.png')

# Clone the original image for displaying the detected faces
detected_faces = mask.copy()

roi_wajah = cascade_wajah.detectMultiScale(mask)
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(detected_faces, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Create subplots to display original and detected faces
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the original image in grayscale
axes[0].imshow(cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[0].set_title('Original Image')

# Plot the image with detected faces in grayscale
axes[1].imshow(cv2.cvtColor(detected_faces, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[1].set_title('Detected Faces')

# Hide the axis labels
for ax in axes:
    ax.axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/fitur-facedet/haarcascade_frontalface_alt.xml')

mjordan = cv2.imread('/content/drive/MyDrive/PCVK/images/mjordan.jpg')

# Clone the original image for displaying the detected faces
detected_faces = mjordan.copy()

roi_wajah = cascade_wajah.detectMultiScale(mjordan)
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(detected_faces, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Create subplots to display original and detected faces
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the original image in grayscale
axes[0].imshow(cv2.cvtColor(mjordan, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[0].set_title('Original Image')

# Plot the image with detected faces in grayscale
axes[1].imshow(cv2.cvtColor(detected_faces, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[1].set_title('Detected Faces')

# Hide the axis labels
for ax in axes:
    ax.axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/fitur-facedet/haarcascade_frontalface_alt.xml')

solvayconf = cv2.imread('/content/drive/MyDrive/PCVK/images/solvayconf.jpg')

# Clone the original image for displaying the detected faces
detected_faces = solvayconf.copy()

roi_wajah = cascade_wajah.detectMultiScale(solvayconf)
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(detected_faces, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Create subplots to display original and detected faces
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the original image
axes[0].imshow(cv2.cvtColor(solvayconf, cv2.COLOR_BGR2RGB))
axes[0].set_title('Original Image')

# Plot the image with detected faces
axes[1].imshow(cv2.cvtColor(detected_faces, cv2.COLOR_BGR2RGB))
axes[1].set_title('Detected Faces')

# Hide the axis labels
for ax in axes:
    ax.axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/fitur-facedet/haarcascade_frontalface_alt.xml')

jokowi = cv.imread('/content/drive/MyDrive/PCVK_MM/week 12/image/jokowi.jpg')
jokowi_rgb = cv.cvtColor(jokowi, cv.COLOR_BGR2RGB)
jokowi_fd = jokowi_rgb.copy()

kartini = cv.imread('/content/drive/MyDrive/PCVK_MM/week 12/image/kartini.jpg',0)
kartini_rgb = cv.cvtColor(kartini, cv.COLOR_BGR2RGB)
kartini_fd = kartini_rgb.copy()

kucing = cv.imread('/content/drive/MyDrive/PCVK_MM/week 12/image/kucing2.jpg',0)
kucing_rgb = cv.cvtColor(kucing, cv.COLOR_BGR2RGB)
kucing_fd = kucing_rgb.copy()

mask = cv.imread('/content/drive/MyDrive/PCVK_MM/week 12/image/mask.png',0)
mask_rgb = cv.cvtColor(mask, cv.COLOR_BGR2RGB)
mask_fd = mask_rgb.copy()

mjordan = cv.imread('/content/drive/MyDrive/PCVK_MM/week 12/image/mjordan.jpg',0)
mjordan_rgb = cv.cvtColor(mjordan, cv.COLOR_BGR2RGB)
mjordan_fd = mjordan_rgb.copy()

solvayconf = cv.imread('/content/drive/MyDrive/PCVK_MM/week 12/image/solvayconf.jpg',0)
solvayconf_rgb = cv.cvtColor(solvayconf, cv.COLOR_BGR2RGB)
solvayconf_fd = solvayconf_rgb.copy()

fd_jokowi = cascade_wajah.detectMultiScale(jokowi_fd)
for(x,y,w,h) in fd_jokowi:
  cv.rectangle(jokowi_fd, (x,y),(x+w,y+h), (0,255,0), 3)
plt.figure(figsize = (10,10))
f, axarr = plt. subplots(1,2,figsize=(8,8))
plt.subplot(121),plt.imshow(jokowi_rgb)
plt.subplot(122),plt.imshow(jokowi_fd)
plt.show()

fd_kartini = cascade_wajah.detectMultiScale(kartini_fd)
for(x,y,w,h) in fd_kartini:
  cv.rectangle(kartini_fd, (x,y),(x+w,y+h), (0,255,0), 3)
plt.figure(figsize = (10,10))
f, axarr = plt. subplots(1,2,figsize=(8,8))
plt.subplot(121),plt.imshow(kartini_rgb,cmap='gray')
plt.subplot(122),plt.imshow(kartini_fd,cmap='gray')
plt.show()

fd_kucing = cascade_wajah.detectMultiScale(kucing_fd)
for(x,y,w,h) in fd_kucing:
  cv.rectangle(kucing_fd, (x,y),(x+w,y+h), (0,255,0), 3)
plt.figure(figsize = (10,10))
f, axarr = plt. subplots(1,2,figsize=(8,8))
plt.subplot(121),plt.imshow(kucing_rgb,cmap='gray')
plt.subplot(122),plt.imshow(kucing_fd,cmap='gray')
plt.show()

fd_mask = cascade_wajah.detectMultiScale(mask_fd)
for(x,y,w,h) in fd_mask:
  cv.rectangle(mask_fd, (x,y),(x+w,y+h), (0,255,0), 5)
plt.figure(figsize = (10,10))
f, axarr = plt. subplots(1,2,figsize=(8,8))
plt.subplot(121),plt.imshow(mask_rgb,cmap='gray')
plt.subplot(122),plt.imshow(mask_fd,cmap='gray')
plt.show()

fd_mjordan = cascade_wajah.detectMultiScale(mjordan_fd)
for(x,y,w,h) in fd_mjordan:
  cv.rectangle(mjordan_fd, (x,y),(x+w,y+h), (0,255,0), 3)
plt.figure(figsize = (10,10))
f, axarr = plt. subplots(1,2,figsize=(8,8))
plt.subplot(121),plt.imshow(mjordan_rgb,cmap='gray')
plt.subplot(122),plt.imshow(mjordan_fd,cmap='gray')
plt.show()

fd_solvayconf = cascade_wajah.detectMultiScale(solvayconf_fd)
for(x,y,w,h) in fd_solvayconf:
  cv.rectangle(solvayconf_fd, (x,y),(x+w,y+h), (0,255,0), 3)
plt.figure(figsize = (10,10))
f, axarr = plt. subplots(1,2,figsize=(8,8))
plt.subplot(121),plt.imshow(solvayconf_rgb,cmap='gray')
plt.subplot(122),plt.imshow(solvayconf_fd,cmap='gray')
plt.show()

# %% [markdown]
# **2.) Wajah kucing tidak bisa dideteksi dengan baik. Lakukan deteksi wajah kucing hingga muncul rectangle pada bagian wajahnya seperti gambar berikut. Petunjuk pada soal ini, perhatikan pretrained features yang telah disediakan OpenCV. Gunakan xml yang ada jika memang telah disediakan.**

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/fitur-facedet/haarcascade_frontalcatface.xml')

cat = cv2.imread('/content/drive/MyDrive/PCVK/images/mycat.jpg')

# Clone the original image for displaying the detected faces
detected_faces = cat.copy()

roi_wajah = cascade_wajah.detectMultiScale(cat)
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(detected_faces, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Create subplots to display original and detected faces
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the original image in grayscale
axes[0].imshow(cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[0].set_title('Original Image')

# Plot the image with detected faces in grayscale
axes[1].imshow(cv2.cvtColor(detected_faces, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[1].set_title('Detected Faces')

# Hide the axis labels
for ax in axes:
    ax.axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **3.) Cobakan juga untuk eyes detection pada gambar “Jokowi.jpg”**

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/fitur-facedet/haarcascade_eye.xml')

jokowi = cv2.imread('/content/drive/MyDrive/PCVK/images/jokowi.jpg')

# Clone the original image for displaying the detected faces
detected_faces = jokowi.copy()

roi_wajah = cascade_wajah.detectMultiScale(jokowi)
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(detected_faces, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Create subplots to display original and detected faces
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the original image in grayscale
axes[0].imshow(cv2.cvtColor(jokowi, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[0].set_title('Original Image')

# Plot the image with detected faces in grayscale
axes[1].imshow(cv2.cvtColor(detected_faces, cv2.COLOR_BGR2GRAY), cmap='gray')
axes[1].set_title('Detected Faces')

# Hide the axis labels
for ax in axes:
    ax.axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
